# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('http://www.ppgia.pucpr.br/~jean.barddal/datascience/titanic.csv')

# %%
df.head(5)
df.info()
#histograma
df['Age'].hist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#histograma(seaborn) -> distplot
sns.distplot(df['Age'], kde=False, bins=10)
plt.show()

# %%
sns.countplot(df['Age'])
plt.show()

# %%
sns.boxplot(df['Age'])
plt.show()

# %%
sns.violinplot(df['Age'])
plt.show()

# %%
df['Embarked'].dropna().value_counts().plot(kind='pie')

# %%
#Comparando as distribuições de idade por sobrevivência ou não

sns.boxplot(df['Survived'], df['Age'])
plt.show()

# %%
#Comparando as distribuições de idade por sexo
sns.boxplot(df['Sex'], df['Age'])
plt.show()

# %%
# Criar a base
df = pd.DataFrame({
    'x' : np.random.normal(10, 1.2, 20000),
    'y' : np.random.normal(10, 1.2, 20000),
    'group' : np.repeat('A', 20000)
})

tmp1 = pd.DataFrame({
    'x' : np.random.normal(14.5, 1.2, 20000),
    'y' : np.random.normal(14.5, 1.2, 20000),
    'group' : np.repeat('B', 20000)
})

tmp2 = pd.DataFrame({
    'x' : np.random.normal(9.5, 1.5, 20000),
    'y' : np.random.normal(15.5, 1.5, 20000),
    'group' : np.repeat('C', 20000)
})

# concatenating the data
df = df.append(tmp1).append(tmp2)

# %%
df.head(5)
# Out:
#            x          y group
# 0  11.600840   9.970269     A
# 1  10.979676  10.194065     A
# 2   8.341551   9.072706     A
# 3  10.778692   9.257098     A
# 4   9.257809  10.473373     A

# %%
df.describe()
# Out:
#                   x             y
# count  60000.000000  60000.000000
# mean      11.340245     13.323761
# std        2.595945      2.725704
# min        3.301745      5.000884
# 25%        9.362925     10.796939
# 50%       10.685040     13.995416
# 75%       13.691735     15.401852
# max       19.786237     22.503061

# %%
sns.distplot(df['x'])
plt.show()

# %%
sns.distplot(df['y'])
plt.show()

# %%
sns.scatterplot(df['x'], df['y'], s=2)
plt.show()

# %%
#transparencia
sns.scatterplot(df['x'], df['y'], alpha=0.01)
plt.show()

# %%
#gráfico de densidade
#densidade 
sns.kdeplot(df['x'], df['y'], shade=True)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#joinplot

sns.jointplot(df['x'], df['y'], kind='kde')
plt.show()

# %%
samp = df.sample(2000)
sns.scatterplot(samp['x'], samp['y'])
plt.show()

# %%
#enfase -> dar mais atenão a um dos grupos
#enfase -> dar masi atenção a um dos grupos
df_a = df[df['group'] == 'A']
df_restante = df[df['group'] != 'A']

sns.scatterplot(df_restante['x'], df_restante['y'], color='red')
sns.scatterplot(df_a['x'], df_a['y'], color='grey')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#facet grid -> facetamento  
#analisar o comportamento de x e y por grupo
g = sns.FacetGrid(df, col="group", hue="group")
g = g.map(plt.scatter, 'x', 'y')
plt.show()

# %%
#criando nova base de dados

a = np.concatenate([
                    np.random.normal(2, 4, 1000),
                    np.random.normal(4, 4, 1000),
                    np.random.normal(1, 2,  500),
                    np.random.normal(10, 2, 500),
                    np.random.normal(8, 4, 1000),
                    np.random.normal(10, 4, 1000)
])

df = pd.DataFrame({
    'x': np.repeat(range(1,6), 1000),
    'y': a
})

# %%
df.head(5)
# Out:
#    x         y
# 0  1  4.877546
# 1  1 -2.051111
# 2  1  6.242080
# 3  1  2.038732
# 4  1  8.276787

# %%
#scatterplot 
sns.scatterplot(df['x'], df['y'])

# %%
#spripsplot
sns.stripplot(df['x'], df['y'])

# %%
#striplot
sns.stripplot(df['x'], df ['y'], jitter=0.3, size=2)

# %%
#striplot
sns.boxplot(df['x'], df['y'])
sns.stripplot(df['x'], df['y'], jitter=0.3, size=1, color='grey')

# %%
#striplot
sns.violinplot(df['x'], df['y'])
sns.stripplot(df['x'], df['y'], jitter=0.3, size=1, color='grey')

# %%
# swarn plots
sns.swarmplot(df['x'], df['y'], color='grey')
